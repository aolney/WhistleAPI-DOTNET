# %% [markdown]
# # F# Whistle API (version 2)
#
# This is v2 of [WhistleAPI-DOTNET](https://github.com/aolney/WhistleAPI-DOTNET).
# The original version was in C# and used WebClient.
# For some reason, it just stopped working.
#
# The same calls work in F# using [Fsharp.Data](https://fsharp.github.io/FSharp.Data/), so I decided to scrap the C# version and create this notebook with the minimal F# code needed to access the API.
#
# The original code was informed by [an old description of the unofficial API](http://jared.wuntu.org/whistle-dog-activity-monitor-undocumented-api/).
# In this new version, I loaded up [Charles Proxy](https://www.charlesproxy.com/) to [intercept encrypted traffic](https://medium.com/@hackupstate/using-charles-proxy-to-debug-android-ssl-traffic-e61fc38760f7) between the [Whistle Legacy app](https://play.google.com/store/apps/details?id=com.whistle.WhistleApp&hl=en_US) and the API endpoints.
# I didn't notice any differences that were breaking, though it seems the app is sending additional information in the headers that's not needed to make the API work.
#
# The entire API has not been implemented; that would be extremely tedious.
# However, unlike v1, I'm providing a semi-complete domain model, using [FSharp.Json](https://vsapronov.github.io/FSharp.Json/) for serialization.
# The API below represents what I consider to be the core interesting API.
# If you want more, then see the comment in `AuthenticatedGet` to return raw JSON.
#
# ## API

# %%
#r "/z/aolney/repos/FSharp.Data.3.1.1/lib/net45/FSharp.Data.dll"
#r "/z/aolney/repos/FSharp.Json.0.4.0/lib/netstandard2.0/FSharp.Json.dll"

open FSharp.Data
open FSharp.Json

// ---- Domain model -----------------------------------------

type Authentication =
    {
        email : string
        password : string
    }
    
type Token = { token : string }
    
type Dog =
    {
        id: string
        city_id: string
        date_of_birth: string
        gender: string
        name: string
        weight: float
        weight_type: string
        age_in_months: int
        age_in_years: int
        breed_id: int
        breed_name: string
        average_minutes_active: float
        average_minutes_rest: float
        average_calories: float
        average_distance: float
        distance_units: string
        location : string
        device_id : string
        device_serial : string
    }
    
type User =
    {
        id : string
        first_name: string
        last_name :string
        email : string
        created_at : string
    }

type Device =
    {
        battery_days_left:  int
        battery_level:  float
        charging:  bool
        device_on:  bool
        firmware_version: string
        last_check_in:  string
        model:  string
        next_check_in:  string
        pending_locate:  bool
        requires_subscription:  bool
        serial_number: string
        tracking:  bool
        tracking_status:  string
    }

type Daily =
    {
        updated_at: string
        timestamp: string
        minutes_active: int
        activity_goal: int
        day_number: int
    }
    
type WEvent =
    {
        id: string
        timeline_id: string
        start_time: string
        end_time: string
        event_type: string
        event_title: string
        event_details: string option
        intensity: string
        minutes_active: int
        manually_created: string option
        share_url: string
        can_destroy: bool
        users: User[]
        current_user_present: bool
    }
    
type Highlight =
    {
        id: string
        timeline_id: string
        start_time: string
        event_type: string
        event_subtype: string
        event_details: string
        author : User
    }
    
type HourlyActivity =
    {
        activity : float option
        rest : float option
        distance : float option
        distance_units : string option
        calories: float option
    }
    
type DetailedDaily =
    {
        share_url : string
        events : WEvent[]
        date : string
        minutes_active: int
        minutes_rest : int
        calories : float
        distance : float
        distance_units : string
        time_zone : string
        last_updated_at : string
        hourly_activity : HourlyActivity[]
        day_number : int
    }
    
type Goal =
    {
        num_days : int
        goals_hit : int
        current_streak : int
        longest_streak : int
    }
    
type Averages =
    {
        average_minutes_active: float
        average_minutes_rest: float
        similar_dogs_minutes_active: float
        similar_dogs_minutes_rest: float
    }
    
type DailyTotal =
    {
        timestamp : string
        minutes_active : int
        minutes_rest : int
    }
    
type HighlightType =
    | Note
    | Food
    | Medication
    override x.ToString() = 
        match x with
        | Note -> "note"
        | Food -> "food"
        | Medication -> "medication"

// ---- Domain model END--------------------------------------

/// All other calls need the token returned
let GetToken authentication = 
    let json = Json.serialize(authentication)
    let response = 
        Http.RequestString(
            "https://app.whistle.com/api/tokens.json", 
            headers = [ HttpRequestHeaders.ContentType HttpContentTypes.Json ],
            body = TextRequest json
        )
    Json.deserialize<Token>(response).token
        
/// A generic GET that takes a type to define type-safe serialization. See the comment for raw JSON.
let AuthenticatedGet<'T> token url =
    let response = 
        Http.RequestString(
            url,
            headers = [ 
                HttpRequestHeaders.ContentType HttpContentTypes.Json
                "X-Whistle-AuthToken", token
                ]
        )
    //response //for raw json
    Json.deserialize<'T>(response) //for properly formatted object

/// Get the user for the device
let GetUser token =
    AuthenticatedGet<User> token "https://app.whistle.com/api/users/"

/// Get data for all dogs. Returns device ids and dog ids needed for other API calls
let GetDogs token = 
    AuthenticatedGet<Dog[]> token "https://app.whistle.com/api/dogs.json"
    
/// Get data for specific dog
let GetDog dogId token =
    AuthenticatedGet<Dog> token ("https://app.whistle.com/api/dogs/" + dogId)
    
/// Get status of Whistle Device
let GetDevice deviceId token = 
    AuthenticatedGet<Device> token ("https://app.whistle.com/api/devices/" + deviceId + ".json")

/// Returns minutes active and activity goal
let GetDailies dogId days token =
    AuthenticatedGet<Daily[]> token ("https://app.whistle.com/api/dogs/" + dogId + "/dailies?count=" + days.ToString())

/// More detailed dailies. The dailyId is returned in GetDailies
let GetDetailedDaily dogId dailyId token =
    AuthenticatedGet<DetailedDaily> token ("https://app.whistle.com/api/dogs/" + dogId + "/dailies/" + dailyId)
    
/// Returns specific WEvent. TimelineId is returned in DetailedDailies
let GetTimeline timelineId token =
    AuthenticatedGet<WEvent> token ("https://app.whistle.com/api/timeline/" +  timelineId)

/// Gets all highlights since the start of time
let GetHighlights dogId highlight token =
    AuthenticatedGet<Highlight[]> token ("https://app.whistle.com/api/dogs/" + dogId + "/highlights?type=" + highlight.ToString())

/// Returns empty, so can't test
let GetUsersPresent dogId token =
    AuthenticatedGet<User[]> token ("https://app.whistle.com/api/dogs/" + dogId + "/stats/users_present")
    
/// Get goals for this dog
let GetGoals dogId token =
    AuthenticatedGet<Goal> token ("https://app.whistle.com/api/dogs/" + dogId + "/stats/goals")
       
/// Returns average minutes active/rest vs similar dogs active/rest
let GetAverages dogId token =
    AuthenticatedGet<Averages> token ("https://app.whistle.com/api/dogs/" + dogId + "/stats/averages")

/// Returns minutes active and minutes rest. Fromdate format "2015-08-30"
let GetDailyTotals dogId fromDate token =
    AuthenticatedGet<DailyTotal[]> token ("https://app.whistle.com/api/dogs/" + dogId + "/stats/daily_totals/?start_time=" + fromDate )

# %% [markdown]
# ## Using the API
#
# The following calls demonstrate how to use the API.

# %%
//You need to insert your account information. The returned token is needed for following calls
let token = GetToken {email="YOUR WHISTLE EMAIL ADDRESS"; password="YOUR WHISTLE PASSWORD"} 
token |> printfn "%A\n"

token |> GetUser |> printfn "%A\n"
token |> GetDogs |> printfn "%A\n"

//Insert the dog id from the GetDogs call
token |> GetDog "5853" |> printfn "%A\n"
token |> GetHighlights "5853" HighlightType.Note |> printfn "%A\n"
token |> GetUserPresent "5853" |> printfn "%A\n"
token |> GetGoals "5853" |> printfn "%A\n"
token |> GetAverages "5853" |> printfn "%A\n"

//Insert the device id from the GetDogs call
token |> GetDevice "6439" |> printfn "%A\n"

//From date is the day you want, going forward to the current date
token |> GetDailyTotals "5853" "2019-11-30" |> printfn "%A\n"

//10 is the number of days you want, going backward from the current date
token |> GetDailies "5853" 10 |> printfn "%A\n"

//Insert a day number from the GetDailies call 
token |> GetDetailedDaily "5853" "18233" |> printfn "%A\n"

//Insert a timeline id from the GetDetailedDaily call
token |> GetTimeline "e486332483" |> printfn "%A\n"
# Out:
# "905aba472b54ea54ab4865d3ef027a02"
#
# {id = "16938";
#  first_name = "Andrew";
#  last_name = "Olney";
#  email = "aolney@memphis.edu";
#  created_at = "2014-06-21T17:14:11Z";}
#
# [|{id = "5853";
#    city_id = "10913";
#    date_of_birth = "2008-01-04";
#    gender = "f";
#    name = "Shiloh";
#    weight = 62.0;
#    weight_type = "pounds";
#    age_in_months = 10;
#    age_in_years = 11;
#    breed_id = 432;
#    breed_name = "German Shepherd Dog";
#    average_minutes_active = 48.31318681;
#    average_minutes_rest = 1050.5;
#    average_calories = 1055.098798;
#    average_distance = 2.84;
#    distance_units = "miles";
#    location = "Memphis, TN";
#    device_id = "6439";
#    device_serial = "W01-00683D";}|]
#
# {id = "5853";
#  city_id = "10913";
#  date_of_birth = "2008-01-04";
#  gender = "f";
#  name = "Shiloh";
#  weight = 62.0;
#  weight_type = "pounds";
#  age_in_months = 10;
#  age_in_years = 11;
#  breed_id = 432;
#  breed_name = "German Shepherd Dog";
#  average_minutes_active = 48.31318681;
#  average_minutes_rest = 1050.5;
#  average_calories = 1055.098798;
#  average_distance = 2.84;
#  distance_units = "miles";
#  location = "Memphis, TN";
#  device_id = "6439";
#  device_serial = "W01-00683D";}
#
# [|{id = "173465";
#    timeline_id = "h173465";
#    start_time = "2015-09-17T12:51:28-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Crated";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "173424";
#    timeline_id = "h173424";
#    start_time = "2015-09-17T08:23:50-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Crated";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "36365";
#    timeline_id = "h36365";
#    start_time = "2014-09-14T16:25:33-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Fart";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "27520";
#    timeline_id = "h27520";
#    start_time = "2014-08-05T22:54:09-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Weird unsettled before walk like bloat";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "25854";
#    timeline_id = "h25854";
#    start_time = "2014-07-30T16:06:11-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Sat behind my chair at 4pm";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "22324";
#    timeline_id = "h22324";
#    start_time = "2014-07-13T10:43:34-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Chill in chill out ten and walk 13 pee";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "22298";
#    timeline_id = "h22298";
#    start_time = "2014-07-13T08:29:00-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Chill walk 18 two poo one fs pee";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "21957";
#    timeline_id = "h21957";
#    start_time = "2014-07-11T08:48:24-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "10  min walk pee poo pool dip ";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "21776";
#    timeline_id = "h21776";
#    start_time = "2014-07-10T07:46:34-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Test2";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "21775";
#    timeline_id = "h21775";
#    start_time = "2014-07-09T07:46:13-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Test";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20579";
#    timeline_id = "h20579";
#    start_time = "2014-07-03T09:23:20-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "8am activity is good baseline for nothing";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20578";
#    timeline_id = "h20578";
#    start_time = "2014-07-03T09:22:42-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Pee poo crated";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20520";
#    timeline_id = "h20520";
#    start_time = "2014-07-02T23:06:31-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Walk 11 pee 4 poo";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20286";
#    timeline_id = "h20286";
#    start_time = "2014-07-01T17:19:02-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Out of crate";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20246";
#    timeline_id = "h20246";
#    start_time = "2014-07-01T12:52:01-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Recreated 5 min ago";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20240";
#    timeline_id = "h20240";
#    start_time = "2014-07-01T12:09:28-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Out of crate 5 -10 min ago";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20213";
#    timeline_id = "h20213";
#    start_time = "2014-07-01T09:26:32-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Crate ";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20074";
#    timeline_id = "h20074";
#    start_time = "2014-06-30T15:15:06-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Getting out of crate";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20061";
#    timeline_id = "h20061";
#    start_time = "2014-06-30T13:30:56-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Crated 1:20";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};};
#   {id = "20035";
#    timeline_id = "h20035";
#    start_time = "2014-06-30T08:31:53-05:00 America/Chicago";
#    event_type = "Highlight";
#    event_subtype = "note";
#    event_details = "Crated";
#    author = {id = "16938";
#              first_name = "Andrew";
#              last_name = "Olney";
#              email = "aolney@memphis.edu";
#              created_at = "2014-06-21T17:14:11Z";};}|]
#
# "[]"
#
# {num_days = 183;
#  goals_hit = 25;
#  current_streak = 0;
#  longest_streak = 298;}
#
# {average_minutes_active = 48.31318681;
#  average_minutes_rest = 1050.5;
#  similar_dogs_minutes_active = 49.26113689;
#  similar_dogs_minutes_rest = 1052.940015;}
#
# {battery_days_left = 5;
#  battery_level = 84.57538885;
#  charging = false;
#  device_on = true;
#  firmware_version = "1.2-131212 :: 2.3-131212 :: 4.19-140428-a";
#  last_check_in = "2019-12-03T15:43:47-06:00 America/Chicago";
#  model = "W01A";
#  next_check_in = "2019-12-03T16:43:47-06:00 America/Chicago";
#  pending_locate = false;
#  requires_subscription = false;
#  serial_number = "W01-00683D";
#  tracking = false;
#  tracking_status = "not_tracking";}
#
# [|{timestamp = "2019-11-30T00:00:00-06:00 America/Chicago";
#    minutes_active = 44;
#    minutes_rest = 1137;};
#   {timestamp = "2019-12-01T00:00:00-06:00 America/Chicago";
#    minutes_active = 69;
#    minutes_rest = 1144;};
#   {timestamp = "2019-12-02T00:00:00-06:00 America/Chicago";
#    minutes_active = 39;
#    minutes_rest = 1077;};
#   {timestamp = "2019-12-03T00:00:00-06:00 America/Chicago";
#    minutes_active = 20;
#    minutes_rest = 470;}|]
#
# [|{updated_at = "2019-12-03T21:43:48Z";
#    timestamp = "2019-12-03T00:00:00-06:00 America/Chicago";
#    minutes_active = 20;
#    activity_goal = 60;
#    day_number = 18233;};
#   {updated_at = "2019-12-03T04:38:24Z";
#    timestamp = "2019-12-02T00:00:00-06:00 America/Chicago";
#    minutes_active = 39;
#    activity_goal = 60;
#    day_number = 18232;};
#   {updated_at = "2019-12-02T12:03:38Z";
#    timestamp = "2019-12-01T00:00:00-06:00 America/Chicago";
#    minutes_active = 69;
#    activity_goal = 60;
#    day_number = 18231;};
#   {updated_at = "2019-12-01T13:45:39Z";
#    timestamp = "2019-11-30T00:00:00-06:00 America/Chicago";
#    minutes_active = 44;
#    activity_goal = 60;
#    day_number = 18230;};
#   {updated_at = "2019-11-30T13:27:35Z";
#    timestamp = "2019-11-29T00:00:00-06:00 America/Chicago";
#    minutes_active = 42;
#    activity_goal = 60;
#    day_number = 18229;};
#   {updated_at = "2019-11-30T11:02:56Z";
#    timestamp = "2019-11-28T00:00:00-06:00 America/Chicago";
#    minutes_active = 58;
#    activity_goal = 60;
#    day_number = 18228;};
#   {updated_at = "2019-11-28T13:22:24Z";
#    timestamp = "2019-11-27T00:00:00-06:00 America/Chicago";
#    minutes_active = 58;
#    activity_goal = 60;
#    day_number = 18227;};
#   {updated_at = "2019-11-27T13:04:34Z";
#    timestamp = "2019-11-26T00:00:00-06:00 America/Chicago";
#    minutes_active = 43;
#    activity_goal = 60;
#    day_number = 18226;};
#   {updated_at = "2019-11-27T11:03:31Z";
#    timestamp = "2019-11-25T00:00:00-06:00 America/Chicago";
#    minutes_active = 48;
#    activity_goal = 60;
#    day_number = 18225;};
#   {updated_at = "2019-11-25T11:48:29Z";
#    timestamp = "2019-11-24T00:00:00-06:00 America/Chicago";
#    minutes_active = 54;
#    activity_goal = 60;
#    day_number = 18224;}|]
#
# {share_url = "https://app.whistle.com/s/9y9jlp";
#  events =
#   [|{id = "486469789";
#      timeline_id = "e486469789";
#      start_time = "2019-12-03T12:58:39-06:00 America/Chicago";
#      end_time = "2019-12-03T15:37:39-06:00 America/Chicago";
#      event_type = "Rest";
#      event_title = "0 minutes";
#      event_details = None;
#      intensity = "moderate";
#      minutes_active = 0;
#      manually_created = None;
#      share_url = "https://app.whistle.com/s/puaw4n";
#      can_destroy = false;
#      users = [||];
#      current_user_present = false;};
#     {id = "486332483";
#      timeline_id = "e486332483";
#      start_time = "2019-12-03T08:15:39-06:00 America/Chicago";
#      end_time = "2019-12-03T10:53:39-06:00 America/Chicago";
#      event_type = "Rest";
#      event_title = "0 minutes";
#      event_details = None;
#      intensity = "moderate";
#      minutes_active = 0;
#      manually_created = None;
#      share_url = "https://app.whistle.com/s/gknqhf";
#      can_destroy = false;
#      users = [||];
#      current_user_present = false;};
#     {id = "486255750";
#      timeline_id = "e486255750";
#      start_time = "2019-12-03T05:56:39-06:00 America/Chicago";
#      end_time = "2019-12-03T06:13:39-06:00 America/Chicago";
#      event_type = "Walk";
#      event_title = "11 minutes";
#      event_details = None;
#      intensity = "moderate";
#      minutes_active = 11;
#      manually_created = None;
#      share_url = "https://app.whistle.com/s/xjpy35";
#      can_destroy = false;
#      users = [||];
#      current_user_present = false;}|];
#  date = "2019-12-03T00:00:00-06:00";
#  minutes_active = 20;
#  minutes_rest = 470;
#  calories = 482.4218073;
#  distance = 1.34;
#  distance_units = "miles";
#  time_zone = "America/Chicago";
#  last_updated_at = "2019-12-03T21:43:48Z";
#  hourly_activity =
#   [|{activity = None;
#      rest = None;
#      distance = None;
#      distance_units = Some "miles";
#      calories = None;}; {activity = None;
#                          rest = None;
#                          distance = None;
#                          distance_units = Some "miles";
#                          calories = None;}; {activity = None;
#                                              rest = None;
#                                              distance = None;
#                                              distance_units = Some "miles";
#                                              calories = None;};
#     {activity = None;
#      rest = None;
#      distance = None;
#      distance_units = Some "miles";
#      calories = None;}; {activity = None;
#                          rest = None;
#                          distance = None;
#                          distance_units = Some "miles";
#                          calories = None;}; {activity = Some 3.748669434;
#                                              rest = Some 6.0;
#                                              distance = Some 0.2578902;
#                                              distance_units = Some "miles";
#                                              calories = Some 36.34200508;};
#     {activity = Some 10.84108966;
#      rest = Some 21.0;
#      distance = Some 0.4795522;
#      distance_units = Some "miles";
#      calories = Some 76.08471467;}; {activity = Some 0.0;
#                                      rest = Some 51.0;
#                                      distance = Some 0.0495711;
#                                      distance_units = Some "miles";
#                                      calories = Some 40.18713661;};
#     {activity = Some 0.0;
#      rest = Some 51.0;
#      distance = Some 0.0702837;
#      distance_units = Some "miles";
#      calories = Some 42.56843945;}; {activity = Some 0.0;
#                                      rest = Some 54.0;
#                                      distance = Some 0.0140491;
#                                      distance_units = Some "miles";
#                                      calories = Some 38.6371279;};
#     {activity = Some 0.0;
#      rest = Some 56.0;
#      distance = Some 0.0232326;
#      distance_units = Some "miles";
#      calories = Some 39.69950722;}; {activity = Some 1.199120032;
#                                      rest = Some 47.0;
#                                      distance = Some 0.1258015;
#                                      distance_units = Some "miles";
#                                      calories = Some 47.49613659;};
#     {activity = Some 3.96768905;
#      rest = Some 38.0;
#      distance = Some 0.2644963;
#      distance_units = Some "miles";
#      calories = Some 58.16587997;}; {activity = Some 0.5933997113;
#                                      rest = Some 56.0;
#                                      distance = Some 0.0308375;
#                                      distance_units = Some "miles";
#                                      calories = Some 40.37574495;};
#     {activity = Some 0.0;
#      rest = Some 57.0;
#      distance = Some 0.0104724;
#      distance_units = Some "miles";
#      calories = Some 38.63115605;}; {activity = Some 0.0;
#                                      rest = Some 33.0;
#                                      distance = Some 0.0151141;
#                                      distance_units = Some "miles";
#                                      calories = Some 24.23395883;};
#     {activity = None;
#      rest = None;
#      distance = None;
#      distance_units = Some "miles";
#      calories = None;}; {activity = None;
#                          rest = None;
#                          distance = None;
#                          distance_units = Some "miles";
#                          calories = None;}; {activity = None;
#                                              rest = None;
#                                              distance = None;
#                                              distance_units = Some "miles";
#                                              calories = None;};
#     {activity = None;
#      rest = None;
#      distance = None;
#      distance_units = Some "miles";
#      calories = None;}; {activity = None;
#                          rest = None;
#                          distance = None;
#                          distance_units = Some "miles";
#                          calories = None;}; {activity = None;
#                                              rest = None;
#                                              distance = None;
#                                              distance_units = Some "miles";
#                                              calories = None;};
#     {activity = None;
#      rest = None;
#      distance = None;
#      distance_units = Some "miles";
#      calories = None;}; {activity = None;
#                          rest = None;
#                          distance = None;
#                          distance_units = Some "miles";
#                          calories = None;}|];
#  day_number = 18233;}
#
# {id = "486332483";
#  timeline_id = "e486332483";
#  start_time = "2019-12-03T08:15:39-06:00 America/Chicago";
#  end_time = "2019-12-03T10:53:39-06:00 America/Chicago";
#  event_type = "Rest";
#  event_title = "0 minutes";
#  event_details = None;
#  intensity = "moderate";
#  minutes_active = 0;
#  manually_created = None;
#  share_url = "https://app.whistle.com/s/gknqhf";
#  can_destroy = false;
#  users = [||];
#  current_user_present = false;}
